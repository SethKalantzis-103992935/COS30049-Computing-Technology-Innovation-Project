# %% [markdown]
# # Asthma-Like Illness Emergency Department Presentations (monthly) | Processing

# %% [markdown]
# The main tasks completed to clean and preprocess this dataset were:
#
# **Data Manipulation**
# 1. Rename columns.
# 2. Move 'date' column to the first position.
# 3. Remove 'LHD' from LHD name values.
# 4. Remove 'All' data (Representing a state-wide average).
# 5. Remove columns holding Confidence Interval data.
# 6. Remove rows holding 'Persons' data in the sex column (Representing a genderless rate per 100,000).

# %% [markdown]
# ## Set Up

# %% [markdown]
# Ensure that the required libraries are available by running the below code in the terminal before execution:
# - pip install pandas
#
#
# Execute the following in the jupyter notebook before execution to ensure that the required libraries are imported:

# %%
import pandas as pd

# %% [markdown]
# ## Load Dataset

# %%
# File path.
file_path = 'data-raw.csv'

# Read the file.
df = pd.read_csv(file_path)

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# Rename columns to match Air Quality data set.

# %%
# Rename columns.
df = df.rename(columns={
    'LHD': 'lhd',
    'Period': 'date'
})

# Set column names to lower case.
df.columns = df.columns.str.lower()

df
# Out:
#           sex         lhd     date  rate per 100,000 population  ll 95% ci  \
# 0       Males  Sydney LHD  2014-07                         22.6       17.4
# 1       Males  Sydney LHD  2014-08                         28.9       22.6
# 2       Males  Sydney LHD  2014-09                         15.7       11.4
# 3       Males  Sydney LHD  2014-10                         19.2       14.2
# 4       Males  Sydney LHD  2014-11                         19.7       14.8
# ...       ...         ...      ...                          ...        ...
# 4855  Persons    All LHDs  2023-02                         24.0       22.9
# 4856  Persons    All LHDs  2023-03                         22.1       21.1
# 4857  Persons    All LHDs  2023-04                         25.0       23.8
# 4858  Persons    All LHDs  2023-05                         30.7       29.5
# 4859  Persons    All LHDs  2023-06                         26.8       25.7
#
#       ul 95% ci
# 0          28.8
# 1          36.2
# 2          21.2
# 3          25.3
# 4          25.8
# ...         ...
# 4855       25.2
# 4856       23.2
# 4857       26.1
# 4858       32.0
# 4859       28.0
#
# [4860 rows x 6 columns]

# %% [markdown]
# Move 'date' column to the first position.

# %%
# Move 'date' column to the first position.
date_col = df.pop('date')
df.insert(0, 'date', date_col)

df
# Out:
#          date      sex         lhd  rate per 100,000 population  ll 95% ci  \
# 0     2014-07    Males  Sydney LHD                         22.6       17.4
# 1     2014-08    Males  Sydney LHD                         28.9       22.6
# 2     2014-09    Males  Sydney LHD                         15.7       11.4
# 3     2014-10    Males  Sydney LHD                         19.2       14.2
# 4     2014-11    Males  Sydney LHD                         19.7       14.8
# ...       ...      ...         ...                          ...        ...
# 4855  2023-02  Persons    All LHDs                         24.0       22.9
# 4856  2023-03  Persons    All LHDs                         22.1       21.1
# 4857  2023-04  Persons    All LHDs                         25.0       23.8
# 4858  2023-05  Persons    All LHDs                         30.7       29.5
# 4859  2023-06  Persons    All LHDs                         26.8       25.7
#
#       ul 95% ci
# 0          28.8
# 1          36.2
# 2          21.2
# 3          25.3
# 4          25.8
# ...         ...
# 4855       25.2
# 4856       23.2
# 4857       26.1
# 4858       32.0
# 4859       28.0
#
# [4860 rows x 6 columns]

# %% [markdown]
# Remove ' LHD' for Local Health District values.

# %%
# Remove ' LHD' from the 'lhd' column.
df['lhd'] = df['lhd'].str.replace(' LHD', '')

# %% [markdown]
# Remove rows representing state-wide aggregated data.

# %%
# Remove rows with 'All' in the 'lhd' column.
df = df[~df['lhd'].str.contains('All')]

# %% [markdown]
# Remove columns holding Confidence Interval data.

# %%
# Drop columns with '% ci' in the header
df = df.loc[:, ~df.columns.str.contains('% ci')]

# %% [markdown]
# Remove rows holding 'Persons' data in the sex column.

# %%
# Drop rows with 'Persons' in the 'sex' column.
df = df[~df['sex'].str.contains('Persons')]

# %% [markdown]
# ## Output Processed Dataset

# %%
# File path.
file_path_output = 'data-processed.csv'

# Save the file.
df.to_csv(file_path_output, index=False)

# %% [markdown]
# ## View Dataset

# %%
df
# Out:
#          date      sex          lhd  rate per 100,000 population
# 0     2014-07    Males       Sydney                         22.6
# 1     2014-08    Males       Sydney                         28.9
# 2     2014-09    Males       Sydney                         15.7
# 3     2014-10    Males       Sydney                         19.2
# 4     2014-11    Males       Sydney                         19.7
# ...       ...      ...          ...                          ...
# 3127  2023-02  Females  Western NSW                         41.4
# 3128  2023-03  Females  Western NSW                         43.3
# 3129  2023-04  Females  Western NSW                         43.9
# 3130  2023-05  Females  Western NSW                         57.7
# 3131  2023-06  Females  Western NSW                         55.6
#
# [3024 rows x 4 columns]

# %% [markdown]
# ## Alternative Approach
# Composite primary key becomes only 'lhd' and 'date'.
#
# Tracks 'Male rate per 100,000 population' and 'Female rate per 100,000 population' on the same row.

# %% [markdown]
# ### Reconfigure Table

# %%
# Pivot the dataframe to have 'sex' as columns
df_alt = df.pivot_table(index=['date', 'lhd'], columns='sex', values='rate per 100,000 population').reset_index()

# Rename the columns to match the desired format
df_alt.columns.name = None
df_alt = df_alt.rename(columns={'Males': 'Male rate per 100,000 population', 'Females': 'Female rate per 100,000 population'})

df_alt
# Out:
#          date                   lhd  Female rate per 100,000 population  \
# 0     2014-07         Central Coast                                29.8
# 1     2014-07    Hunter New England                                45.3
# 2     2014-07  Illawarra Shoalhaven                                42.1
# 3     2014-07       Mid North Coast                                58.4
# 4     2014-07          Murrumbidgee                                46.2
# ...       ...                   ...                                 ...
# 1507  2023-06  South Western Sydney                                18.9
# 1508  2023-06          Southern NSW                                29.7
# 1509  2023-06                Sydney                                16.9
# 1510  2023-06           Western NSW                                55.6
# 1511  2023-06        Western Sydney                                15.3
#
#       Male rate per 100,000 population
# 0                                 21.8
# 1                                 32.3
# 2                                 26.7
# 3                                 35.5
# 4                                 51.4
# ...                                ...
# 1507                              18.4
# 1508                              40.7
# 1509                              14.4
# 1510                              38.1
# 1511                              18.3
#
# [1512 rows x 4 columns]

# %% [markdown]
# ### Output Alternative Processed Dataset

# %%
# File path.
file_path_output_alt = 'data-processed-alt.csv'

# Save the file.
df_alt.to_csv(file_path_output_alt, index=False)
