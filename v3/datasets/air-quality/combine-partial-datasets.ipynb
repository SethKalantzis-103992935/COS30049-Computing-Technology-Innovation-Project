# %% [markdown]
# # NSW Air Quality Monthly Averages 2000 - 2024 | Combine Partial Datasets
# Dataset downloaded in 4-year chunks to avoid gateway timeout on airquality.nsw.go.au. This notebook outlines the process for combining these disjointed datasets into one.
#
# No additional pre-processing or cleaning is completed in this workflow. This work takes place in a separate file

# %% [markdown]
# ## Dependencies

# %% [markdown]
# Ensure that the required libraries have been installed locally as per the README.md file included in this project.
#
# Run the following cell the import the required dependencies for this notebook.

# %%
import pandas as pd

# Allows access to xls data format. #todo: check if this is necessary
# %pip install xlrd
# Out:
# Requirement already satisfied: xlrd in c:\users\matth\anaconda3\lib\site-packages (2.0.1)Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load Raw Disjointed Data

# %%
# Load the raw data
data_2000 = pd.read_excel('partial-datasets/2000-2003-raw.xls')
data_2004 = pd.read_excel('partial-datasets/2004-2007-raw.xls')
data_2008 = pd.read_excel('partial-datasets/2008-2011-raw.xls')
data_2012 = pd.read_excel('partial-datasets/2012-2015-raw.xls')
data_2016 = pd.read_excel('partial-datasets/2016-2019-raw.xls')
data_2020 = pd.read_excel('partial-datasets/2020-2024-raw.xls')

# List of datasets
datasets = [data_2000, data_2004, data_2008, data_2012, data_2016, data_2020]
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero

# %% [markdown]
# ## Exploratory Analysis of Raw Disjointed Data

# %%
# Year being displayed
year = 2000
# Display the head of each dataset
for dataset in datasets:
    print(f"Partial Dataset {year}-{year + 3} Head:")
    display(dataset.head())
    year += 4
# Out:
# Partial Dataset 2000-2003 Head:
#   Monthly Averages Time Range: 01/01/2000 00:00 to 01/01/2004 00:00  \
# 0                                       Initial Data
# 1                                               Date
# 2                                         31/01/2000
# 3                                         29/02/2000
# 4                                         31/03/2000
#
#                             Unnamed: 1                          Unnamed: 2  \
# 0              RANDWICK SO2 1h average              ROZELLE SO2 1h average
# 1  RANDWICK SO2 monthly average [pphm]  ROZELLE SO2 monthly average [pphm]
# 2                                  0.1                                 NaN
# 3                                  0.1                                 NaN
# 4                                  NaN                                 NaN
#
#                              Unnamed: 3                            Unnamed: 4  \
# 0              LINDFIELD SO2 1h average              LIVERPOOL SO2 1h average
# 1  LINDFIELD SO2 monthly average [pphm]  LIVERPOOL SO2 monthly average [pphm]
# 2                                   0.1                                   NaN
# 3                                   0.1                                   NaN
# 4                                   0.1                                   NaN
#
#                              Unnamed: 5                           Unnamed: 6  \
# 0              BRINGELLY SO2 1h average              CHULLORA SO2 1h average
# 1  BRINGELLY SO2 monthly average [pphm]  CHULLORA SO2 monthly average [pphm]
# 2                                     0                                  NaN
# 3                                   0.1                                  NaN
# 4                                     0                                  NaN
#
#                          Unnamed: 7                           Unnamed: 8  \
# 0              WYONG SO2 1h average              WALLSEND SO2 1h average
# 1  WYONG SO2 monthly average [pphm]  WALLSEND SO2 monthly average [pphm]
# 2                               NaN                                  0.2
# 3                               NaN                                  0.2
# 4                               NaN                                  0.2
#
#                               Unnamed: 9  ...  \
# 0              CARRINGTON SO2 1h average  ...
# 1  CARRINGTON SO2 monthly average [pphm]  ...
# 2                                    NaN  ...
# 3                                    NaN  ...
# 4                                    NaN  ...
#
#                               Unnamed: 246  \
# 0               BERESFIELD PM10 1h average
# 1  BERESFIELD PM10 monthly average [µg/m³]
# 2                                     16.8
# 3                                     20.3
# 4                                     17.9
#
#                             Unnamed: 247  \
# 0               TAMWORTH PM10 1h average
# 1  TAMWORTH PM10 monthly average [µg/m³]
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                               Unnamed: 248  \
# 0               WOLLONGONG PM10 1h average
# 1  WOLLONGONG PM10 monthly average [µg/m³]
# 2                                     18.3
# 3                                     27.8
# 4                                     21.8
#
#                                  Unnamed: 249  \
# 0               KEMBLA GRANGE PM10 1h average
# 1  KEMBLA GRANGE PM10 monthly average [µg/m³]
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                             Unnamed: 250                        Unnamed: 251  \
# 0               RICHMOND PM10 1h average               BARGO PM10 1h average
# 1  RICHMOND PM10 monthly average [µg/m³]  BARGO PM10 monthly average [µg/m³]
# 2                                   15.3                                 NaN
# 3                                   21.2                                 NaN
# 4                                     15                                 NaN
#
#                           Unnamed: 252  \
# 0               ALBURY PM10 1h average
# 1  ALBURY PM10 monthly average [µg/m³]
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                                Unnamed: 253  \
# 0               WAGGA WAGGA PM10 1h average
# 1  WAGGA WAGGA PM10 monthly average [µg/m³]
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                             Unnamed: 254  \
# 0               ST MARYS PM10 1h average
# 1  ST MARYS PM10 monthly average [µg/m³]
# 2                                   16.9
# 3                                   21.5
# 4                                   15.7
#
#                             Unnamed: 255
# 0               VINEYARD PM10 1h average
# 1  VINEYARD PM10 monthly average [µg/m³]
# 2                                   15.5
# 3                                   18.5
# 4                                   14.5
#
# [5 rows x 256 columns]
# Partial Dataset 2004-2007 Head:
#   Monthly Averages Time Range: 01/01/2004 00:00 to 01/01/2008 00:00  \
# 0                                       Initial Data
# 1                                               Date
# 2                                         31/01/2004
# 3                                         29/02/2004
# 4                                         31/03/2004
#
#                             Unnamed: 1                          Unnamed: 2  \
# 0              RANDWICK SO2 1h average              ROZELLE SO2 1h average
# 1  RANDWICK SO2 monthly average [pphm]  ROZELLE SO2 monthly average [pphm]
# 2                                  0.1                                 NaN
# 3                                  0.1                                 NaN
# 4                                  0.1                                 NaN
#
#                              Unnamed: 3                            Unnamed: 4  \
# 0              LINDFIELD SO2 1h average              LIVERPOOL SO2 1h average
# 1  LINDFIELD SO2 monthly average [pphm]  LIVERPOOL SO2 monthly average [pphm]
# 2                                   0.1                                   NaN
# 3                                   0.1                                   NaN
# 4                                   0.1                                   NaN
#
#                              Unnamed: 5                           Unnamed: 6  \
# 0              BRINGELLY SO2 1h average              CHULLORA SO2 1h average
# 1  BRINGELLY SO2 monthly average [pphm]  CHULLORA SO2 monthly average [pphm]
# 2                                     0                                  NaN
# 3                                     0                                  NaN
# 4                                     0                                  NaN
#
#                          Unnamed: 7                           Unnamed: 8  \
# 0              WYONG SO2 1h average              WALLSEND SO2 1h average
# 1  WYONG SO2 monthly average [pphm]  WALLSEND SO2 monthly average [pphm]
# 2                               NaN                                  NaN
# 3                               NaN                                  0.1
# 4                               NaN                                  0.1
#
#                               Unnamed: 9  ...  \
# 0              CARRINGTON SO2 1h average  ...
# 1  CARRINGTON SO2 monthly average [pphm]  ...
# 2                                    NaN  ...
# 3                                    NaN  ...
# 4                                    NaN  ...
#
#                               Unnamed: 246  \
# 0               BERESFIELD PM10 1h average
# 1  BERESFIELD PM10 monthly average [µg/m³]
# 2                                     20.4
# 3                                     24.6
# 4                                     22.2
#
#                             Unnamed: 247  \
# 0               TAMWORTH PM10 1h average
# 1  TAMWORTH PM10 monthly average [µg/m³]
# 2                                   18.4
# 3                                   20.4
# 4                                   17.8
#
#                               Unnamed: 248  \
# 0               WOLLONGONG PM10 1h average
# 1  WOLLONGONG PM10 monthly average [µg/m³]
# 2                                     24.5
# 3                                     27.4
# 4                                     24.2
#
#                                  Unnamed: 249  \
# 0               KEMBLA GRANGE PM10 1h average
# 1  KEMBLA GRANGE PM10 monthly average [µg/m³]
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                             Unnamed: 250                        Unnamed: 251  \
# 0               RICHMOND PM10 1h average               BARGO PM10 1h average
# 1  RICHMOND PM10 monthly average [µg/m³]  BARGO PM10 monthly average [µg/m³]
# 2                                   22.8                                 NaN
# 3                                   23.9                                 NaN
# 4                                   21.7                                 NaN
#
#                           Unnamed: 252  \
# 0               ALBURY PM10 1h average
# 1  ALBURY PM10 monthly average [µg/m³]
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#                                Unnamed: 253  \
# 0               WAGGA WAGGA PM10 1h average
# 1  WAGGA WAGGA PM10 monthly average [µg/m³]
# 2                                      25.3
# 3                                      33.3
# 4                                      44.4
#
#                             Unnamed: 254  \
# 0               ST MARYS PM10 1h average
# 1  ST MARYS PM10 monthly average [µg/m³]
# 2                                   23.6
# 3                                   25.1
# 4                                   20.1
#
#                             Unnamed: 255
# 0               VINEYARD PM10 1h average
# 1  VINEYARD PM10 monthly average [µg/m³]
# 2                                   21.1
# 3                                   21.9
# 4                                   20.2
#
# [5 rows x 256 columns]
# Partial Dataset 2008-2011 Head:
#   Monthly Averages Time Range: 01/01/2008 00:00 to 01/12/2011 00:00  \
# 0                                       Initial Data
# 1                                               Date
# 2                                         31/01/2008
# 3                                         29/02/2008
# 4                                         31/03/2008
#
#                             Unnamed: 1                          Unnamed: 2  \
# 0              RANDWICK SO2 1h average              ROZELLE SO2 1h average
# 1  RANDWICK SO2 monthly average [pphm]  ROZELLE SO2 monthly average [pphm]
# 2                                    0                                 NaN
# 3                                    0                                 NaN
# 4                                  0.1                                 NaN
#
#                              Unnamed: 3                            Unnamed: 4  \
# 0              LINDFIELD SO2 1h average              LIVERPOOL SO2 1h average
# 1  LINDFIELD SO2 monthly average [pphm]  LIVERPOOL SO2 monthly average [pphm]
# 2                                   NaN                                   NaN
# 3                                     0                                   NaN
# 4                                     0                                   NaN
#
#                              Unnamed: 5                           Unnamed: 6  \
# 0              BRINGELLY SO2 1h average              CHULLORA SO2 1h average
# 1  BRINGELLY SO2 monthly average [pphm]  CHULLORA SO2 monthly average [pphm]
# 2                                   0.1                                  0.1
# 3                                   0.1                                    0
# 4                                     0                                    0
#
#                          Unnamed: 7                           Unnamed: 8  \
# 0              WYONG SO2 1h average              WALLSEND SO2 1h average
# 1  WYONG SO2 monthly average [pphm]  WALLSEND SO2 monthly average [pphm]
# 2                               NaN                                  0.1
# 3                               NaN                                  0.2
# 4                               NaN                                  0.1
#
#                               Unnamed: 9  ...  \
# 0              CARRINGTON SO2 1h average  ...
# 1  CARRINGTON SO2 monthly average [pphm]  ...
# 2                                    NaN  ...
# 3                                    NaN  ...
# 4                                    NaN  ...
#
#                               Unnamed: 246  \
# 0               BERESFIELD PM10 1h average
# 1  BERESFIELD PM10 monthly average [µg/m³]
# 2                                       19
# 3                                     16.7
# 4                                     19.9
#
#                             Unnamed: 247  \
# 0               TAMWORTH PM10 1h average
# 1  TAMWORTH PM10 monthly average [µg/m³]
# 2                                   10.9
# 3                                   11.4
# 4                                   16.4
#
#                               Unnamed: 248  \
# 0               WOLLONGONG PM10 1h average
# 1  WOLLONGONG PM10 monthly average [µg/m³]
# 2                                     22.4
# 3                                       17
# 4                                     18.7
#
#                                  Unnamed: 249  \
# 0               KEMBLA GRANGE PM10 1h average
# 1  KEMBLA GRANGE PM10 monthly average [µg/m³]
# 2                                        21.2
# 3                                        15.7
# 4                                        19.3
#
#                             Unnamed: 250                        Unnamed: 251  \
# 0               RICHMOND PM10 1h average               BARGO PM10 1h average
# 1  RICHMOND PM10 monthly average [µg/m³]  BARGO PM10 monthly average [µg/m³]
# 2                                   17.1                                 NaN
# 3                                   12.5                                 NaN
# 4                                   14.5                                 NaN
#
#                           Unnamed: 252  \
# 0               ALBURY PM10 1h average
# 1  ALBURY PM10 monthly average [µg/m³]
# 2                                   22
# 3                                 18.4
# 4                                 27.4
#
#                                Unnamed: 253  \
# 0               WAGGA WAGGA PM10 1h average
# 1  WAGGA WAGGA PM10 monthly average [µg/m³]
# 2                                       NaN
# 3                                      23.1
# 4                                      36.6
#
#                             Unnamed: 254  \
# 0               ST MARYS PM10 1h average
# 1  ST MARYS PM10 monthly average [µg/m³]
# 2                                   18.8
# 3                                   13.8
# 4                                   16.1
#
#                             Unnamed: 255
# 0               VINEYARD PM10 1h average
# 1  VINEYARD PM10 monthly average [µg/m³]
# 2                                   17.1
# 3                                   13.3
# 4                                   15.1
#
# [5 rows x 256 columns]
# Partial Dataset 2012-2015 Head:
#   Monthly Averages Time Range: 01/01/2012 00:00 to 01/01/2016 00:00  \
# 0                                       Initial Data
# 1                                               Date
# 2                                         31/01/2012
# 3                                         29/02/2012
# 4                                         31/03/2012
#
#                             Unnamed: 1                          Unnamed: 2  \
# 0              RANDWICK SO2 1h average              ROZELLE SO2 1h average
# 1  RANDWICK SO2 monthly average [pphm]  ROZELLE SO2 monthly average [pphm]
# 2                                  0.1                                 NaN
# 3                                  0.1                                 NaN
# 4                                  0.1                                 NaN
#
#                              Unnamed: 3                            Unnamed: 4  \
# 0              LINDFIELD SO2 1h average              LIVERPOOL SO2 1h average
# 1  LINDFIELD SO2 monthly average [pphm]  LIVERPOOL SO2 monthly average [pphm]
# 2                                     0                                   NaN
# 3                                   0.1                                   NaN
# 4                                     0                                   NaN
#
#                              Unnamed: 5                           Unnamed: 6  \
# 0              BRINGELLY SO2 1h average              CHULLORA SO2 1h average
# 1  BRINGELLY SO2 monthly average [pphm]  CHULLORA SO2 monthly average [pphm]
# 2                                     0                                    0
# 3                                     0                                  0.1
# 4                                     0                                  0.1
#
#                          Unnamed: 7                           Unnamed: 8  \
# 0              WYONG SO2 1h average              WALLSEND SO2 1h average
# 1  WYONG SO2 monthly average [pphm]  WALLSEND SO2 monthly average [pphm]
# 2                               NaN                                  0.1
# 3                               NaN                                  0.1
# 4                               NaN                                    0
#
#                               Unnamed: 9  ...  \
# 0              CARRINGTON SO2 1h average  ...
# 1  CARRINGTON SO2 monthly average [pphm]  ...
# 2                                    NaN  ...
# 3                                    NaN  ...
# 4                                    NaN  ...
#
#                               Unnamed: 246  \
# 0               BERESFIELD PM10 1h average
# 1  BERESFIELD PM10 monthly average [µg/m³]
# 2                                     20.6
# 3                                     16.5
# 4                                     17.2
#
#                             Unnamed: 247  \
# 0               TAMWORTH PM10 1h average
# 1  TAMWORTH PM10 monthly average [µg/m³]
# 2                                   12.5
# 3                                   11.4
# 4                                   12.3
#
#                               Unnamed: 248  \
# 0               WOLLONGONG PM10 1h average
# 1  WOLLONGONG PM10 monthly average [µg/m³]
# 2                                     20.2
# 3                                     15.7
# 4                                     16.5
#
#                                  Unnamed: 249  \
# 0               KEMBLA GRANGE PM10 1h average
# 1  KEMBLA GRANGE PM10 monthly average [µg/m³]
# 2                                        18.9
# 3                                        13.1
# 4                                          17
#
#                             Unnamed: 250                        Unnamed: 251  \
# 0               RICHMOND PM10 1h average               BARGO PM10 1h average
# 1  RICHMOND PM10 monthly average [µg/m³]  BARGO PM10 monthly average [µg/m³]
# 2                                     15                                16.4
# 3                                   11.6                                12.8
# 4                                   11.4                                12.3
#
#                           Unnamed: 252  \
# 0               ALBURY PM10 1h average
# 1  ALBURY PM10 monthly average [µg/m³]
# 2                                 13.9
# 3                                 12.7
# 4                                 13.3
#
#                                Unnamed: 253  \
# 0               WAGGA WAGGA PM10 1h average
# 1  WAGGA WAGGA PM10 monthly average [µg/m³]
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                             Unnamed: 254  \
# 0               ST MARYS PM10 1h average
# 1  ST MARYS PM10 monthly average [µg/m³]
# 2                                   15.5
# 3                                   11.6
# 4                                   12.9
#
#                             Unnamed: 255
# 0               VINEYARD PM10 1h average
# 1  VINEYARD PM10 monthly average [µg/m³]
# 2                                   15.4
# 3                                   11.9
# 4                                     12
#
# [5 rows x 256 columns]
# Partial Dataset 2016-2019 Head:
#   Monthly Averages Time Range: 01/01/2016 00:00 to 01/01/2020 00:00  \
# 0                                       Initial Data
# 1                                               Date
# 2                                         31/01/2016
# 3                                         29/02/2016
# 4                                         31/03/2016
#
#                             Unnamed: 1                          Unnamed: 2  \
# 0              RANDWICK SO2 1h average              ROZELLE SO2 1h average
# 1  RANDWICK SO2 monthly average [pphm]  ROZELLE SO2 monthly average [pphm]
# 2                                  0.1                                 0.1
# 3                                  0.1                                 0.1
# 4                                  0.1                                 0.1
#
#                              Unnamed: 3                            Unnamed: 4  \
# 0              LINDFIELD SO2 1h average              LIVERPOOL SO2 1h average
# 1  LINDFIELD SO2 monthly average [pphm]  LIVERPOOL SO2 monthly average [pphm]
# 2                                     0                                   NaN
# 3                                   0.1                                   NaN
# 4                                   0.1                                   NaN
#
#                              Unnamed: 5                           Unnamed: 6  \
# 0              BRINGELLY SO2 1h average              CHULLORA SO2 1h average
# 1  BRINGELLY SO2 monthly average [pphm]  CHULLORA SO2 monthly average [pphm]
# 2                                     0                                    0
# 3                                     0                                  0.1
# 4                                   0.1                                  0.1
#
#                          Unnamed: 7                           Unnamed: 8  \
# 0              WYONG SO2 1h average              WALLSEND SO2 1h average
# 1  WYONG SO2 monthly average [pphm]  WALLSEND SO2 monthly average [pphm]
# 2                               0.1                                  0.1
# 3                               0.1                                  0.1
# 4                               0.1                                  0.1
#
#                               Unnamed: 9  ...  \
# 0              CARRINGTON SO2 1h average  ...
# 1  CARRINGTON SO2 monthly average [pphm]  ...
# 2                                    0.2  ...
# 3                                    0.2  ...
# 4                                    0.2  ...
#
#                               Unnamed: 246  \
# 0               BERESFIELD PM10 1h average
# 1  BERESFIELD PM10 monthly average [µg/m³]
# 2                                     19.6
# 3                                     22.1
# 4                                     17.4
#
#                             Unnamed: 247  \
# 0               TAMWORTH PM10 1h average
# 1  TAMWORTH PM10 monthly average [µg/m³]
# 2                                   13.4
# 3                                   17.9
# 4                                   15.7
#
#                               Unnamed: 248  \
# 0               WOLLONGONG PM10 1h average
# 1  WOLLONGONG PM10 monthly average [µg/m³]
# 2                                     21.9
# 3                                     21.7
# 4                                     18.6
#
#                                  Unnamed: 249  \
# 0               KEMBLA GRANGE PM10 1h average
# 1  KEMBLA GRANGE PM10 monthly average [µg/m³]
# 2                                          23
# 3                                        24.7
# 4                                          21
#
#                             Unnamed: 250                        Unnamed: 251  \
# 0               RICHMOND PM10 1h average               BARGO PM10 1h average
# 1  RICHMOND PM10 monthly average [µg/m³]  BARGO PM10 monthly average [µg/m³]
# 2                                   15.1                                15.2
# 3                                     18                                16.6
# 4                                   15.6                                14.7
#
#                           Unnamed: 252  \
# 0               ALBURY PM10 1h average
# 1  ALBURY PM10 monthly average [µg/m³]
# 2                                 14.6
# 3                                 20.8
# 4                                 20.1
#
#                                Unnamed: 253  \
# 0               WAGGA WAGGA PM10 1h average
# 1  WAGGA WAGGA PM10 monthly average [µg/m³]
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                             Unnamed: 254  \
# 0               ST MARYS PM10 1h average
# 1  ST MARYS PM10 monthly average [µg/m³]
# 2                                   16.5
# 3                                   21.4
# 4                                   14.8
#
#                             Unnamed: 255
# 0               VINEYARD PM10 1h average
# 1  VINEYARD PM10 monthly average [µg/m³]
# 2                                   16.7
# 3                                   20.7
# 4                                   17.5
#
# [5 rows x 256 columns]
# Partial Dataset 2020-2023 Head:
#   Monthly Averages Time Range: 01/01/2020 00:00 to 01/09/2024 00:00  \
# 0                                       Initial Data
# 1                                               Date
# 2                                         31/01/2020
# 3                                         29/02/2020
# 4                                         31/03/2020
#
#                             Unnamed: 1                          Unnamed: 2  \
# 0              RANDWICK SO2 1h average              ROZELLE SO2 1h average
# 1  RANDWICK SO2 monthly average [pphm]  ROZELLE SO2 monthly average [pphm]
# 2                                    0                                   0
# 3                                  0.1                                   0
# 4                                  0.1                                 0.1
#
#                              Unnamed: 3                            Unnamed: 4  \
# 0              LINDFIELD SO2 1h average              LIVERPOOL SO2 1h average
# 1  LINDFIELD SO2 monthly average [pphm]  LIVERPOOL SO2 monthly average [pphm]
# 2                                   NaN                                   NaN
# 3                                   NaN                                   0.1
# 4                                   NaN                                     0
#
#                              Unnamed: 5                           Unnamed: 6  \
# 0              BRINGELLY SO2 1h average              CHULLORA SO2 1h average
# 1  BRINGELLY SO2 monthly average [pphm]  CHULLORA SO2 monthly average [pphm]
# 2                                     0                                  0.1
# 3                                     0                                  0.1
# 4                                   NaN                                    0
#
#                          Unnamed: 7                           Unnamed: 8  \
# 0              WYONG SO2 1h average              WALLSEND SO2 1h average
# 1  WYONG SO2 monthly average [pphm]  WALLSEND SO2 monthly average [pphm]
# 2                               0.1                                  0.3
# 3                               0.1                                  0.1
# 4                                 0                                  0.1
#
#                               Unnamed: 9  ...  \
# 0              CARRINGTON SO2 1h average  ...
# 1  CARRINGTON SO2 monthly average [pphm]  ...
# 2                                    0.1  ...
# 3                                      0  ...
# 4                                      0  ...
#
#                               Unnamed: 246  \
# 0               BERESFIELD PM10 1h average
# 1  BERESFIELD PM10 monthly average [µg/m³]
# 2                                     35.6
# 3                                     19.4
# 4                                     15.8
#
#                             Unnamed: 247  \
# 0               TAMWORTH PM10 1h average
# 1  TAMWORTH PM10 monthly average [µg/m³]
# 2                                   41.9
# 3                                   12.5
# 4                                   11.9
#
#                               Unnamed: 248  \
# 0               WOLLONGONG PM10 1h average
# 1  WOLLONGONG PM10 monthly average [µg/m³]
# 2                                     45.5
# 3                                     24.5
# 4                                     17.3
#
#                                  Unnamed: 249  \
# 0               KEMBLA GRANGE PM10 1h average
# 1  KEMBLA GRANGE PM10 monthly average [µg/m³]
# 2                                        50.3
# 3                                        23.8
# 4                                          20
#
#                             Unnamed: 250                        Unnamed: 251  \
# 0               RICHMOND PM10 1h average               BARGO PM10 1h average
# 1  RICHMOND PM10 monthly average [µg/m³]  BARGO PM10 monthly average [µg/m³]
# 2                                   47.6                                  54
# 3                                   18.1                                18.3
# 4                                   14.1                                  14
#
#                           Unnamed: 252  \
# 0               ALBURY PM10 1h average
# 1  ALBURY PM10 monthly average [µg/m³]
# 2                                 78.6
# 3                                 32.1
# 4                                 18.3
#
#                                Unnamed: 253  \
# 0               WAGGA WAGGA PM10 1h average
# 1  WAGGA WAGGA PM10 monthly average [µg/m³]
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                             Unnamed: 254  \
# 0               ST MARYS PM10 1h average
# 1  ST MARYS PM10 monthly average [µg/m³]
# 2                                   52.7
# 3                                   19.6
# 4                                   16.4
#
#                             Unnamed: 255
# 0               VINEYARD PM10 1h average
# 1  VINEYARD PM10 monthly average [µg/m³]
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
# [5 rows x 256 columns]

# %% [markdown]
# ## Combine Datasets

# %%
# Set appropriate column names for each dataset.
for dataset in datasets:
    dataset.columns = dataset.iloc[1]
    dataset = dataset.iloc[2:]

# Concatenate the datasets.
combined_dataset = pd.concat(datasets)

# %% [markdown]
# ## Output Combine Raw Dataset

# %%
# Save the concatenated dataset.
combined_dataset.to_excel('raw-combined.xlsx', index=False, engine='openpyxl')

# %% [markdown]
# ## View Combined Raw Dataset

# %%
print("Combined Dataset Head:")             
display(combined_dataset.head())         

print("Combined Dataset Tail:")             
display(combined_dataset.tail())
# Out:
# Combined Dataset Head:
# 1          Date  RANDWICK SO2 monthly average [pphm]  \
# 0  Initial Data              RANDWICK SO2 1h average
# 1          Date  RANDWICK SO2 monthly average [pphm]
# 2    31/01/2000                                  0.1
# 3    29/02/2000                                  0.1
# 4    31/03/2000                                  NaN
#
# 1  ROZELLE SO2 monthly average [pphm]  LINDFIELD SO2 monthly average [pphm]  \
# 0              ROZELLE SO2 1h average              LINDFIELD SO2 1h average
# 1  ROZELLE SO2 monthly average [pphm]  LINDFIELD SO2 monthly average [pphm]
# 2                                 NaN                                   0.1
# 3                                 NaN                                   0.1
# 4                                 NaN                                   0.1
#
# 1  LIVERPOOL SO2 monthly average [pphm]  BRINGELLY SO2 monthly average [pphm]  \
# 0              LIVERPOOL SO2 1h average              BRINGELLY SO2 1h average
# 1  LIVERPOOL SO2 monthly average [pphm]  BRINGELLY SO2 monthly average [pphm]
# 2                                   NaN                                     0
# 3                                   NaN                                   0.1
# 4                                   NaN                                     0
#
# 1  CHULLORA SO2 monthly average [pphm]  WYONG SO2 monthly average [pphm]  \
# 0              CHULLORA SO2 1h average              WYONG SO2 1h average
# 1  CHULLORA SO2 monthly average [pphm]  WYONG SO2 monthly average [pphm]
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
#
# 1  WALLSEND SO2 monthly average [pphm]  CARRINGTON SO2 monthly average [pphm]  \
# 0              WALLSEND SO2 1h average              CARRINGTON SO2 1h average
# 1  WALLSEND SO2 monthly average [pphm]  CARRINGTON SO2 monthly average [pphm]
# 2                                  0.2                                    NaN
# 3                                  0.2                                    NaN
# 4                                  0.2                                    NaN
#
# 1  ...  BERESFIELD PM10 monthly average [µg/m³]  \
# 0  ...               BERESFIELD PM10 1h average
# 1  ...  BERESFIELD PM10 monthly average [µg/m³]
# 2  ...                                     16.8
# 3  ...                                     20.3
# 4  ...                                     17.9
#
# 1  TAMWORTH PM10 monthly average [µg/m³]  \
# 0               TAMWORTH PM10 1h average
# 1  TAMWORTH PM10 monthly average [µg/m³]
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
# 1  WOLLONGONG PM10 monthly average [µg/m³]  \
# 0               WOLLONGONG PM10 1h average
# 1  WOLLONGONG PM10 monthly average [µg/m³]
# 2                                     18.3
# 3                                     27.8
# 4                                     21.8
#
# 1  KEMBLA GRANGE PM10 monthly average [µg/m³]  \
# 0               KEMBLA GRANGE PM10 1h average
# 1  KEMBLA GRANGE PM10 monthly average [µg/m³]
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# 1  RICHMOND PM10 monthly average [µg/m³]  BARGO PM10 monthly average [µg/m³]  \
# 0               RICHMOND PM10 1h average               BARGO PM10 1h average
# 1  RICHMOND PM10 monthly average [µg/m³]  BARGO PM10 monthly average [µg/m³]
# 2                                   15.3                                 NaN
# 3                                   21.2                                 NaN
# 4                                     15                                 NaN
#
# 1  ALBURY PM10 monthly average [µg/m³]  \
# 0               ALBURY PM10 1h average
# 1  ALBURY PM10 monthly average [µg/m³]
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
# 1  WAGGA WAGGA PM10 monthly average [µg/m³]  \
# 0               WAGGA WAGGA PM10 1h average
# 1  WAGGA WAGGA PM10 monthly average [µg/m³]
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
# 1  ST MARYS PM10 monthly average [µg/m³]  \
# 0               ST MARYS PM10 1h average
# 1  ST MARYS PM10 monthly average [µg/m³]
# 2                                   16.9
# 3                                   21.5
# 4                                   15.7
#
# 1  VINEYARD PM10 monthly average [µg/m³]
# 0               VINEYARD PM10 1h average
# 1  VINEYARD PM10 monthly average [µg/m³]
# 2                                   15.5
# 3                                   18.5
# 4                                   14.5
#
# [5 rows x 256 columns]
# Combined Dataset Tail:
# 1         Date RANDWICK SO2 monthly average [pphm]  \
# 53  30/04/2024                                 0.1
# 54  31/05/2024                                 0.1
# 55  30/06/2024                                 0.1
# 56  31/07/2024                                 0.1
# 57  31/08/2024                                 0.1
#
# 1  ROZELLE SO2 monthly average [pphm] LINDFIELD SO2 monthly average [pphm]  \
# 53                                0.1                                  NaN
# 54                                0.1                                  NaN
# 55                                  0                                  NaN
# 56                                  0                                  NaN
# 57                                0.1                                  NaN
#
# 1  LIVERPOOL SO2 monthly average [pphm] BRINGELLY SO2 monthly average [pphm]  \
# 53                                  0.1                                    0
# 54                                  0.1                                    0
# 55                                  0.1                                    0
# 56                                    0                                    0
# 57                                  0.1                                    0
#
# 1  CHULLORA SO2 monthly average [pphm] WYONG SO2 monthly average [pphm]  \
# 53                                 NaN                                0
# 54                                 NaN                                0
# 55                                 NaN                                0
# 56                                 NaN                                0
# 57                                 NaN                              0.1
#
# 1  WALLSEND SO2 monthly average [pphm] CARRINGTON SO2 monthly average [pphm]  \
# 53                                 0.2                                   0.2
# 54                                 0.2                                   0.2
# 55                                 0.2                                   0.3
# 56                                 0.2                                   0.2
# 57                                 0.1                                   0.2
#
# 1   ... BERESFIELD PM10 monthly average [µg/m³]  \
# 53  ...                                    15.5
# 54  ...                                    14.8
# 55  ...                                    12.8
# 56  ...                                    13.1
# 57  ...                                    16.2
#
# 1  TAMWORTH PM10 monthly average [µg/m³]  \
# 53                                  12.1
# 54                                    13
# 55                                  12.3
# 56                                  10.5
# 57                                  13.8
#
# 1  WOLLONGONG PM10 monthly average [µg/m³]  \
# 53                                    15.8
# 54                                    12.9
# 55                                     9.5
# 56                                     9.7
# 57                                    14.8
#
# 1  KEMBLA GRANGE PM10 monthly average [µg/m³]  \
# 53                                       21.8
# 54                                       16.5
# 55                                       11.4
# 56                                       14.5
# 57                                       22.6
#
# 1  RICHMOND PM10 monthly average [µg/m³] BARGO PM10 monthly average [µg/m³]  \
# 53                                  13.6                               14.1
# 54                                  11.3                               10.7
# 55                                   9.2                                8.6
# 56                                   8.6                                7.9
# 57                                  13.1                               13.8
#
# 1  ALBURY PM10 monthly average [µg/m³]  \
# 53                                23.5
# 54                                24.2
# 55                                11.7
# 56                                10.5
# 57                                13.3
#
# 1  WAGGA WAGGA PM10 monthly average [µg/m³]  \
# 53                                      NaN
# 54                                      NaN
# 55                                      NaN
# 56                                      NaN
# 57                                      NaN
#
# 1  ST MARYS PM10 monthly average [µg/m³] VINEYARD PM10 monthly average [µg/m³]
# 53                                  15.6                                   NaN
# 54                                  11.7                                   NaN
# 55                                  10.3                                   NaN
# 56                                  10.9                                   NaN
# 57                                  13.2                                   NaN
#
# [5 rows x 256 columns]
